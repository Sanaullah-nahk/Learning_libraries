# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Import

# %%
df = pd.read_csv('data\ComputerSales.csv')
df.head()
# Out:
#    Sale ID      Contact Sex  Age State Product ID Product Type  Sale Price  \
# 0        1  Paul Thomas   M   43    OH  M01-F0024      Desktop      479.99
# 1        2  Margo Simms   F   37    WV  GT13-0024      Desktop     1249.99
# 2        3    Sam Stine   M   26    PA      I3670      Desktop      649.99
# 3        4   Moe Eggert   M   35    PA      I3593       Laptop      399.99
# 4        5  Jessica Elk   F   55    PA     15M-ED       Laptop      699.99
#
#    Profit     Lead     Month  Year
# 0  143.39  Website   January  2018
# 1  230.89  Flyer 4   January  2018
# 2  118.64  Website  February  2018
# 3   72.09  Website     March  2018
# 4   98.09  Flyer 4     March  2018

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
df3 = sns.load_dataset('anagrams')
df3.head(10)
# Out:
#    subidr    attnr  num1  num2  num3
# 0       1  divided     2   4.0     7
# 1       2  divided     3   4.0     5
# 2       3  divided     3   5.0     6
# 3       4  divided     5   7.0     5
# 4       5  divided     4   5.0     8
# 5       6  divided     5   5.0     6
# 6       7  divided     5   4.5     6
# 7       8  divided     5   7.0     8
# 8       9  divided     2   3.0     7
# 9      10  divided     6   5.0     6

# %%
df1 = sns.load_dataset('car_crashes')
print(df1.shape)
df1.head()
# Out:
# (51, 8)
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %% [markdown]
# # Distribution plot

# %%
sns.displot(df1['not_distracted'], kde=True, bins=25 );

# %% [markdown]
# # joint plot

# %%
sns.jointplot(x='speeding', y='alcohol', data=df1, kind='hex')

# %% [markdown]
# # KDE plot

# %%
sns.kdeplot(df1['alcohol']);

# %% [markdown]
# # pairplots

# %%
sns.pairplot(df1);

# %% [markdown]
# > **other Dataset**

# %%
df2 = sns.load_dataset('tips')
df2.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.pairplot(df2, hue='sex') #,palette='Blues')

# %% [markdown]
# ###  Rugplot

# %%
plt.figure(figsize=(8,4))
sns.rugplot(df2.tip)
# Out:
# <AxesSubplot:xlabel='tip'>

# %% [markdown]
# # styling

# %%
# white, darkgrid, whitegrid, dark, ticks
sns.set_style('white')

plt.figure(figsize=(6,4))
plt.xticks(range(1,10,1))
plt.title('Banana', fontsize=16)
plt.xlabel('Tip is Custom tabel', fontsize=14)
plt.xlabel('Tip is Custom tabel', fontsize=14)

# Make plot
#sns.displot(df1['not_distracted'], kde=True, bins=25 );
sns.histplot(df2.tip,kde=True);

# %% [markdown]
# ## Matplotlib and seaborn together

# %%
x_1 = np.linspace(0,5,10)
y_1 = x_1**2

# %%
fig1 = plt.figure(figsize=(10,6))
plt.tight_layout()
fig1.subplots_adjust( wspace=.9) #width space
kwargs_main  = { 'fontsize':16} 
fig1.suptitle('This is a somewhat long figure title', **kwargs_main )


##### Apple Plot
ax1 = plt.subplot(1,2,1)
plt.plot(x_1, y_1, 'r')
ax1.set_title('Matplotlib', fontsize=14)
plt.grid(True, color = '0.5')   #add grid

##### Banana Plot
ax2 = plt.subplot(1,2,2) 

sns.histplot(df2.tip,kde=True, color='#DDFFDD', edgecolor="#6A9662")
plt.plot(x_1, y_1, 'r')

plt.grid(True, color = '0.8', dashes=(5,5,0,0))   #add grid
ax2.set_facecolor('linen')
ax2.set_title('Seabonr', fontsize=14);
ax2.set_xlabel('Tips is new custom label')
# Out:
# Text(0.5, 0, 'Tips is new custom label')

# %% [markdown]
# # Categorical Plots
# ### Bar Plots

# %%
# Focus on distributions using categorical data in reference to one of the numerical
# columns

# Aggregate categorical data based on a function (mean is the default)
# Estimate total bill amount based on sex
# With estimator you can define functions to use other than the mean like those
# provided by NumPy : median, std, var, cov or make your own functions
plt.figure(figsize=(6,4))
sns.barplot(x='sex',y='total_bill',data=df2);

# %%
plt.figure(figsize=(6,4))
sns.histplot(df2.sex);

# %%
df2.to_csv('tips.csv', index=False)

# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

df = pd.DataFrame({'Age': np.random.randint(20, 60, 200)})

plt.figure(figsize=(15, 10))
values, bins, bars = plt.hist(df['Age'], edgecolor='white', bins=30)
plt.ylabel("Number of Patients")
plt.xlabel("Number of Patients")
plt.title = ('Age Distrubtion')
plt.bar_label(bars, fontsize=20, color='navy')
plt.margins(x=0.01, y=0.1)
plt.show()

# %% [markdown]
# ## another example

# %%
url = 'https://raw.githubusercontent.com/jpiedehierroa/files/main/Libro1.csv'
df = pd.read_csv(url)

# reshape the dataframe
ct = pd.crosstab(df.countries, df.type)


# total medals per country, which is necessary to sort the bars
ct['tot'] = ct.sum(axis=1)

# sort
ct = ct.sort_values(by='tot', ascending=False)
ct.head()
# Out:
# type       bronze  gold  silver  tot
# countries
# USA            33    39      41  113
# China          18    38      32   88
# ROC            23    20      28   71
# GB             22    22      21   65
# Japan          17    27      14   58

# %%
colors = ("#CD7F32", "silver", "gold")
cd = dict(zip(ct.columns, colors))

# plot the medals columns
title = 'Country Medal Count for Tokyo 2020'
ax = ct.iloc[:, :-1].plot(kind='bar', stacked=True, color=cd, title=title,
                          figsize=(12, 5), rot=0, width=1, ec='k' )

# annotate each container with individual values
for c in ax.containers:
    ax.bar_label(c, label_type='center')
    
# annotate the top containers with the cumulative sum
ax.bar_label(ax.containers[2], padding=3)

# pad the spacing between the number and the edge of the figure
ax.margins(y=0.1)
