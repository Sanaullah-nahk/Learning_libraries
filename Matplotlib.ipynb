# %%
# https://www.youtube.com/watch?v=wB9C0Mz9gSo

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # function plots

# %%
x_1 = np.linspace(0,5,10)
y_1 = x_1**2

plt.plot(x_1, y_1)
plt.title('Days Squared Chart')

plt.xlabel('Days')
plt.ylabel('Days squared')
# Out:
# Text(0, 0.5, 'Days squared')

# %% [markdown]
# # Multiple plots

# %%
fig1 = plt.figure(figsize=(10,6))
plt.tight_layout()
fig1.subplots_adjust( wspace=.9) #width space
kwargs_main  = { 'fontsize':16} 
fig1.suptitle('This is a somewhat long figure title', **kwargs_main )


##### Apple Plot
ax1 = plt.subplot(1,2,1)
plt.plot(x_1, y_1, 'r')
ax1.set_title('Apple')
plt.grid(True, color = '0.5')   #add grid

##### Banana Plot
ax2 = plt.subplot(1,2,2)
plt.plot(x_1, y_1, 'b')
plt.grid(True, color = '0.8', dashes=(5,5,0,0))   #add grid
ax2.set_facecolor('linen')
ax2.set_title('Banana');

# %% [markdown]
# # Using Figure Objects

# %%
fig1 = plt.figure(figsize=(5,4), dpi=100)
axes_1 = fig1.add_axes([0.1, 0.1, 0.9,0.9])   # ***

axes_1.set_xlabel('Days')
axes_1.set_ylabel('Days Squared')
axes_1.set_title('Days Squared Chart')

axes_1.plot(x_1, y_1, label = 'x/x²')
axes_1.plot(y_1, x_1, label = 'x²/x')

axes_1.legend(loc=0)

# *** Adds axes with a   left,   bottom,   width,   height      that ranges from 0 to 1
#     which is the percent of the canvas you want to use

###################################################
# Adds axes with a left, bottom, width and height 
axes_2 = fig1.add_axes([0.38, 0.39, 0.44,0.5])
axes_2.set_xlabel('Days')
axes_2.set_ylabel('Days Squared')
axes_2.set_title('Days Squared Chart')
axes_2.plot(x_1, y_1, 'r', label = 'x/x²')
axes_2.legend(loc=0)

# %% [markdown]
# # sub plots

# %%
fig2, ax2 = plt.subplots(figsize=(10,6), nrows=2, ncols=3 )
plt.tight_layout()
fig2.subplots_adjust(hspace=.4, wspace=.26)

kwargs_main  = {'x':0.5, 'y':1.06, 'fontsize':16} 
fig2.suptitle('This is a somewhat long figure title', **kwargs_main )

ax2[0,0].set_title('plot [0,0]' ,fontsize=14);
ax2[0,0].set_xlabel('Days');
ax2[0,0].set_ylabel('Days squared');

ax2[0,0].set_xticks(range(0,26,5))
ax2[0,0].set_yticks(range(0,26,2))

ax2[0,0].plot(x_1,y_1, label='x / x²',marker='.');
ax2[0,0].plot(y_1,x_1, label='x² / x', marker='.');
ax2[0,0].legend(loc=0);

ax2[0,0].text(6,15,'Multi plot');

########################################################
ax2[0,1].set_title('plot [0,1]', fontsize=14);
ax2[0,1].set_xlabel('Days');
ax2[0,1].set_ylabel('Days squared');

ax2[0,1].scatter(x_1,y_1, label='x / x²');
ax2[0,1].text(1,15,'scatter Plot');
ax2[0,1].legend(loc=(0.05,0.85));

ax2[0,1].grid(True, color = '0.8', dashes=(5,5,0,0))
ax2[0,1].set_facecolor('linen')

########################################################
ax2[0,2].set_title('plot [0,2]', fontsize=14);
ax2[0,2].set_xlabel('Days');
ax2[0,2].set_ylabel('Days squared');

ax2[0,2].bar(x_1,y_1, width= 0.4)
ax2[0,2].plot(x_1,y_1, label='x / x²',marker='.', color='orange');
ax2[0,2].text(0,15,'Bar and line Plot');
ax2[0,2].legend(loc=0);

########################################################
gaussian_numbers = np.random.normal(size=10000)
ax2[1,0].set_title('plot [1,0]', fontsize=14);
ax2[1,0].set_xlabel('values');
ax2[1,0].set_ylabel('frequency');

ax2[1,0].hist(gaussian_numbers, bins=100, label = 'gaussian');
ax2[1,0].text(1.5,250,'Histogram');
ax2[1,0].text(-4,250,'density=False')
ax2[1,0].legend(loc=2);

########################################################
gaussian_numbers = np.random.randn(500)
ax2[1,1].set_title('plot [1,1]', fontsize=14);
ax2[1,1].set_xlabel('values');
ax2[1,1].set_ylabel('Density');

ax2[1,1].hist(gaussian_numbers, bins=30, density=True, stacked=True, edgecolor="#6A9662", color="#DDFFDD", label = 'normal');
ax2[1,1].legend(loc=0);

##########################################################
ax2[1,2].set_title('plot [1,2]', fontsize=14);
ax2[1,2].set_xlabel('Days');
ax2[1,2].set_ylabel('Days squared');

ax2[1,2].step(x_1,y_1, label='x / x²');
ax2[1,2].text(1,15,'Step Plot');
ax2[1,2].legend(loc=(0.05,0.85));

# %% [markdown]
# ### Appearance Options

# %%
fig3 = plt.figure(figsize=(6,4))
ax3 = fig3.add_axes([0,0,1,1])       #Take Full axes


ax3.set_xlabel('Days')
ax3.set_ylabel('Days Squared')
ax3.set_title('Days Squared Chart')

ax3.set_xticks(range(0,6,1))
ax3.set_yticks(range(0,26,1))

ax3.plot(x_1, y_1,
         color='navy', alpha=.9, linewidth=2, linestyle='-.',                                          #line style
         marker = 'o', markersize=7, markerfacecolor = 'y', markeredgecolor= 'r', markeredgewidth='2') # Marker Settings


ax3.set_xlim([0,3])    #to zoom in on X
ax3.set_ylim([0,8])    # to zoom in on Y


ax3.grid(True, color = '0.8', dashes=(5,5,0,0))   #add grid
ax3.set_facecolor('linen')                        #change backgroud

# %% [markdown]
# ### Working with Pandas DataFrame

# %%
df = pd.read_csv('data\icecreamsales.csv')
df = df.sort_values('Temperature')
df.head()
# Out:
#     Temperature  Sales
# 0            37    292
# 1            40    228
# 11           40    320
# 2            49    324
# 10           53    324

# %%
temp = np.array(df.Temperature)
sales = np.array(df.Sales)

# %%
fig4 = plt.figure(figsize = (6,4))
ax4 = fig4.add_axes([0,0,1,1])

ax4.set_xlabel('Temerature')
ax4.set_ylabel('Sales')
ax4.set_title('Icecream sales Vs Sales')

ax4.plot(temp,sales);
ax4.bar(temp, sales);

# Add Annotations by supplying the x & y to point at and the position of the text
# based off of lower left had corner being 0,0
ax4.annotate('Good Month', xy=(81, 556), xytext=(60, 550),
             arrowprops=dict(facecolor='black', shrink=0.05))
# Out:
# Text(60, 550, 'Good Month')

# %% [markdown]
# # Text styles

# %%
# You can use a subset of TeX markup by placing text between $
# matplotlib.org/tutorials/text/mathtext.html
fig_5 = plt.figure(figsize=(5,4),dpi=100)
axes_5 = fig_5.add_axes([0.1,0.1,0.9,0.9])

# All listed plus kappa, iota, zeta, nu, rho, eta, xi, omicron, gamma, tau, phi, 
# chi, psi, delta (Capitalize the first letter for uppercase)
axes_5.text(0, 23, 
            r'$\alpha \beta \sigma \omega \epsilon \mu \pi \theta \lambda$', fontsize=18)
# Subscripts, multiletter superscript, sum, fractions, binomial
axes_5.text(0, 18, 
            r'$\delta_i \gamma^{ij} \sum_{i=0}^\infty x_i \frac{3}{4} \binom{3}{4}$', 
            fontsize=18)
# Another fraction, sqrt, cbrt, trig functions : 
axes_5.text(0, 13, 
            r'$\frac{8 - \frac{x}{5}}{8} \sqrt{9} \sin(\pi) \sqrt[3]{8} \acute a \div$', 
            fontsize=18)
axes_5.text(0, 8, 
            r'$\bar a \hat a \tilde a \vec a \overline {a} \lim_{x \to 2} f(x) = 5$', 
            fontsize=18)
axes_5.text(0, 3, 
            r'$\geq \leq \ne$', 
            fontsize=18)
axes_5.plot(x_1,y_1)

# %% [markdown]
# # Hist

# %%
a1 = np.random.randint(1,7,10000) 
a2 = np.random.randint(1,7,10000)
a3 = a1+a2

plt.hist(a3,bins=11, density=True, width=0.5);
plt.xticks(range(1,13,1));

# %% [markdown]
# #### Another example

# %%
# Import Data
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/diamonds.csv')
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
# Plot
fig, axes = plt.subplots(1, 5, figsize=(10,2.5), dpi=100, sharex=True, sharey=True)
colors = ['tab:red', 'tab:blue', 'tab:green', 'tab:pink', 'tab:olive']

for i, (ax, cut) in enumerate(zip(axes.flatten(), df.cut.unique())):
    x = df.loc[df.cut==cut, 'depth']
    ax.hist(x, alpha=0.5, bins=100, density=True, stacked=False, label=str(cut), color=colors[i])
    ax.set_title(cut)

plt.suptitle('Probability Histogram of Diamond Depths', y=1.05, size=16)
ax.set_xlim(50, 70); ax.set_ylim(0, 1);
plt.tight_layout();

# %%
df.depth.hist(bins=30, density=True);

# %%
fig = plt.figure(figsize=(6,4))
ax = fig.add_axes([0,0,1,1])

ax.hist(df.depth, bins=50, density=True, stacked=True, edgecolor="#6A9662", color="#DDFFDD", label = 'normal');
ax.legend(loc=0);

ax.set_title('Depth', fontsize=16);
ax.set_xlabel('Values', fontsize=12);
ax.set_ylabel('Fequency', fontsize=12);

ax.set_xticks(range(int(min(df.depth)),int(max(df.depth)+1),2));
ax.set_yticks(np.arange(0,0.40,0.03));


# Bins reprsent the number of options available 2 thru 12 = 11
# Density returns the frequency of each bin
# Range gets tuple with bin range interested in
# cumulative=True use a cumulative distribution
# histtype='step' genrates a line plot
# orientation='horizontal' 
# color='orange' change bar color

# %% [markdown]
# ###  Labels

# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

df = pd.DataFrame({'Age': np.random.randint(20, 60, 200)})

plt.figure(figsize=(15, 10))
values, bins, bars = plt.hist(df['Age'], edgecolor='white')
plt.ylabel("Number of Patients")
plt.xlabel("Number of Patients")
plt.title('Age Distrubtion')
plt.bar_label(bars, fontsize=20, color='navy')
plt.margins(x=0.01, y=0.1)
plt.show()
